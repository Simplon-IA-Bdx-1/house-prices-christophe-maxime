# %% [markdown]
# # Linear Regression on House Prices (1D) with Keras
#
# All Rights Reserved © <a href="http://www.louisdorard.com">Louis Dorard</a>
#
# <img src="http://s3.louisdorard.com.s3.amazonaws.com/DL_icon.png">

# %% [markdown]
# In this notebook we show how to perform linear regression on house prices data, using Keras.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
train_full = pd.read_csv('data/train.csv')
test_full = pd.read_csv('data/test.csv')

# %% [markdown]
# ## Define `X_train` and `y_train`
#
# Run [House Prices 1D](House-Prices-1D.ipynb) notebook to create `data`

# %%
#%run House-Prices-1D.ipynb

# %% [markdown]
# Output is `SalePrice`

# %%
Y_train = train_full.SalePrice.values.astype(float)

# %% [markdown]
# Use `Surface` as our only feature

# %%
from numpy import transpose
X_train = transpose([train_full.GrLivArea.values.astype(float)])

# %%
X_train.shape
# Out:
# (1460, 1)

# %% [markdown]
# ## Visualize data in 2D
#
# Initialize plotting lib

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
plt.style.use('dark_background')

# %% [markdown]
# Plot data as yellow dots (achieved with `"y."` option):

# %%
plt.plot(X_train, Y_train, "y.")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The idea here is to find a line that "fits" the data.

# %% [markdown]
# ## About Keras
#
# * High-level API: describe NN structure in simple and convenient way
# * Exists in TensorFlow, and outside (can use other libraries such as MXNet as numerical backend)

# %% [markdown]
# Scale features
#
# "Normalizing" the data should help prevent values from "exploding":

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)

# %% [markdown]
# ## Model relationship between `x` and  `y`
#
# We're looking for `W` and `b` such that <!-- .element: class="fragment" -->
#
# `x * W + b` is a good approximation of `y` <!-- .element: class="fragment" -->
#
# for all `(x, y)` input-output pairs in training. <!-- .element: class="fragment" -->

# %% [markdown]
# Main model type in Keras is sequence of "layers", called `Sequential`. In our case:
#
# * 1 input layer (for `x`)
# * 1 output layer (for `y`)

# %%
from tensorflow.keras.models import Sequential
model = Sequential()

# %% [markdown]
# Define input layer. Number of neurons = number of features in `x`.

# %%
from tensorflow.keras.layers import Input
model.add(Input(shape=X_train.shape[1:]))

# %% [markdown]
# Define output layer, with 1 neuron.

# %% [markdown]
# `Dense` creates _fully-connected_ layer.

# %%
from tensorflow.keras.layers import Dense
model.add(Dense(1))

# %% [markdown]
# Alternative network creation:

# %%
model = Sequential([
    Input(shape=X_train.shape[1:]),
    Dense(1)
])

# %% [markdown]
# ## Choose "loss" to minimize
#
# * Error = difference between prediction `x * W + b` and true output `y`
# * Compute Mean Squared Error over whole dataset
# * MSE is a "loss function"; the smaller, the better
# * Loss value depends on `W`, `b`, and dataset
#     * => We want values of `W` and `b` that minimize loss on given training set.

# %%
loss = 'mse'

# %% [markdown]
# ## Set up optimizer and "compile" model
#
# Idea: iterative way to find lowest point of mountain, blindfolded?
#
# * “What is the direction of steepest descent under my feet?” => _gradient_
# * Follow gradient by a certain step size, called _learning step_ (or _learning rate_ ).
#
# This is called _(Stochastic) Gradient Descent_.

# %% [markdown]
# ![Gradient Descent - Aurélien Géron](figures/GD-Geron.png)

# %% [markdown]
# (See Figure 4-3 in _Hands-on ML_ book by Aurélien Géron)

# %% [markdown]
# In Keras, optimizer is specified when "compiling" model.
#
# (Last step to fix model training code!)

# %%
from tensorflow.keras.optimizers import SGD
LEARNING_RATE = 0.01
model.compile(loss=loss, optimizer=SGD(lr=LEARNING_RATE))

# %% [markdown]
# Remarks:
#
# * Procedure starts from random value => need to consider random number generator seed!
# * Figure is in 1D, but 2 Dimensions when going down a mountain...
# * Our linear regression problem is in 2D, because 2 parameters to learn (`W` and `b`)
# * Benefits of "compiling" to be discussed in future notebook.

# %% [markdown]
# ## Fit model (i.e. run optimization)
#
# The model still hasn't "seen" any data yet...
#
# * With SGD we can choose the amount of data to be used to compute the loss function (`BATCH_SIZE`). This can be useful when the whole dataset doesn't fit in memory. We'll revisit this later!
# * We need to choose for how many iterations to run SGD (`EPOCHS`).
# * The `fit` method is a loop over epochs and batches!

# %%
BATCH_SIZE = X_train.shape[0] # computing the loss over the whole dataset
EPOCHS = 100 # how many iterations over the whole dataset
history = model.fit(X_train, Y_train, epochs=EPOCHS, batch_size=BATCH_SIZE)
# Out:
# Train on 1460 samples
# Epoch 1/100
# 1460/1460 [==============================] - 1s 648us/sample - loss: 39039344640.0000
# Epoch 2/100
# 1460/1460 [==============================] - 0s 2us/sample - loss: 37617725440.0000
# Epoch 3/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 36252401664.0000
# Epoch 4/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 34941136896.0000
# Epoch 5/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 33681811456.0000
# Epoch 6/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 32472350720.0000
# Epoch 7/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 31310780416.0000
# Epoch 8/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 30195214336.0000
# Epoch 9/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 29123819520.0000
# Epoch 10/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 28094855168.0000
# Epoch 11/100
# 1460/1460 [==============================] - 0s 7us/sample - loss: 27106635776.0000
# Epoch 12/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 26157549568.0000
# Epoch 13/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 25246052352.0000
# Epoch 14/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 24370640896.0000
# Epoch 15/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 23529904128.0000
# Epoch 16/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 22722457600.0000
# Epoch 17/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 21946986496.0000
# Epoch 18/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 21202223104.0000
# Epoch 19/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 20486952960.0000
# Epoch 20/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 19800008704.0000
# Epoch 21/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 19140265984.0000
# Epoch 22/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 18506647552.0000
# Epoch 23/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 17898123264.0000
# Epoch 24/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 17313699840.0000
# Epoch 25/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 16752411648.0000
# Epoch 26/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 16213352448.0000
# Epoch 27/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 15695641600.0000
# Epoch 28/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 15198434304.0000
# Epoch 29/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 14720912384.0000
# Epoch 30/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 14262298624.0000
# Epoch 31/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 13821855744.0000
# Epoch 32/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 13398847488.0000
# Epoch 33/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 12992591872.0000
# Epoch 34/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 12602420224.0000
# Epoch 35/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 12227700736.0000
# Epoch 36/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 11867823104.0000
# Epoch 37/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 11522196480.0000
# Epoch 38/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 11190255616.0000
# Epoch 39/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 10871458816.0000
# Epoch 40/100
# 1460/1460 [==============================] - 0s 7us/sample - loss: 10565288960.0000
# Epoch 41/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 10271241216.0000
# Epoch 42/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 9988835328.0000
# Epoch 43/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 9717615616.0000
# Epoch 44/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 9457135616.0000
# Epoch 45/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 9206972416.0000
# Epoch 46/100
# 1460/1460 [==============================] - 0s 7us/sample - loss: 8966714368.0000
# Epoch 47/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 8735970304.0000
# Epoch 48/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 8514363904.0000
# Epoch 49/100
# 1460/1460 [==============================] - 0s 8us/sample - loss: 8301533696.0000
# Epoch 50/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 8097130496.0000
# Epoch 51/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 7900820480.0000
# Epoch 52/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 7712287232.0000
# Epoch 53/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 7531216384.0000
# Epoch 54/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 7357319168.0000
# Epoch 55/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 7190308352.0000
# Epoch 56/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 7029910016.0000
# Epoch 57/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 6875862528.0000
# Epoch 58/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 6727918592.0000
# Epoch 59/100
# 1460/1460 [==============================] - 0s 7us/sample - loss: 6585829376.0000
# Epoch 60/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 6449368064.0000
# Epoch 61/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 6318309376.0000
# Epoch 62/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 6192442880.0000
# Epoch 63/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 6071561216.0000
# Epoch 64/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 5955464192.0000
# Epoch 65/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 5843964928.0000
# Epoch 66/100
# 1460/1460 [==============================] - 0s 7us/sample - loss: 5736881152.0000
# Epoch 67/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 5634038784.0000
# Epoch 68/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 5535267840.0000
# Epoch 69/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 5440409088.0000
# Epoch 70/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 5349306880.0000
# Epoch 71/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 5261811712.0000
# Epoch 72/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 5177781760.0000
# Epoch 73/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 5097079296.0000
# Epoch 74/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 5019572736.0000
# Epoch 75/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 4945135104.0000
# Epoch 76/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 4873646080.0000
# Epoch 77/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 4804987392.0000
# Epoch 78/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 4739046912.0000
# Epoch 79/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 4675718656.0000
# Epoch 80/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 4614897152.0000
# Epoch 81/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 4556484608.0000
# Epoch 82/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 4500386816.0000
# Epoch 83/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 4446508544.0000
# Epoch 84/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 4394764800.0000
# Epoch 85/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 4345070080.0000
# Epoch 86/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 4297341440.0000
# Epoch 87/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 4251504640.0000
# Epoch 88/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 4207483392.0000
# Epoch 89/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 4165205248.0000
# Epoch 90/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 4124600576.0000
# Epoch 91/100
# 1460/1460 [==============================] - 0s 3us/sample - loss: 4085604096.0000
# Epoch 92/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 4048151808.0000
# Epoch 93/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 4012182528.0000
# Epoch 94/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 3977637632.0000
# Epoch 95/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 3944461824.0000
# Epoch 96/100
# 1460/1460 [==============================] - 0s 5us/sample - loss: 3912598272.0000
# Epoch 97/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 3881997824.0000
# Epoch 98/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 3852608512.0000
# Epoch 99/100
# 1460/1460 [==============================] - 0s 6us/sample - loss: 3824382464.0000
# Epoch 100/100
# 1460/1460 [==============================] - 0s 4us/sample - loss: 3797274624.0000

# %% [markdown]
# [Plot data again](#Visualize-data).

# %% [markdown]
# ### Reset model
#
# Simplest way to reset all weights & biases is to re-execute the definition of `model`.
#
# We can then fit again.

# %% [markdown]
# ## Review learning curve

# %%
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
#plt.gca().set_ylim(0, 1)
plt.title('Model performance throughout training')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## Visualize model

# %% [markdown]
# * Model is line defined by coefficient `W` and bias (a.k.a. intercept) `b`
# * Just need to plot 2 points and link them...
#     * x-axis: let's choose minimum and maximum of `X_train`
#     * y-axis: given by model's predictions

# %%
import numpy as np
x_line = np.transpose([[X_train.min(), X_train.max()]])
y_line = model.predict(x_line)

# %%
print("Point 1: [" + str(x_line[0][0]) + ", " + str(y_line[0]) + " ]")
print("Point 2: [" + str(x_line[1][0]) + ", " + str(y_line[1]) + " ]")
# Out:
# Point 1: [-2.2491201474608564, [47142.836] ]
# Point 2: [7.855574356961303, [540376.06] ]

# %%
# %matplotlib notebook
plt.plot(X_train, Y_train, "b.")
plt.plot(x_line, y_line, "r-") # "r-" means we plot data points in red and link them with a line
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
predict = model.predict(X_train)
model.evaluate(predict, Y_train, verbose=0)
# Out:
# 6.4351798470967435e+19

# %% [markdown]
# Might want to increase learning rate?

# %% [markdown]
# ## Change learning rate

# %% [markdown]
# ### Learning rate too small
#
# The loss decrease is too slow
#
# ![Gradient Descent with a small learning step - Aurélien Géron](figures/GD-small-learning-rate-Geron.png)

# %% [markdown]
# (See Figure 4-4 in _Hands-on ML_ book by Aurélien Géron)

# %% [markdown]
# ### Learning rate too big
#
# Depending on the initialization, it could converge slowly, or it could diverge
#
# ![Gradient Descent with a big learning step - Aurélien Géron](figures/GD-big-learning-rate-Geron.png)

# %% [markdown]
# (See Figure 4-5 in _Hands-on ML_ book by Aurélien Géron)

# %% [markdown]
# ### Modification du modèle
